# %%
from utils.investor_decision_handling import create_decision_workflow
from IPython.display import display, Image

graph = create_decision_workflow()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from utils.investor_decision_handling import create_decision_workflow
from IPython.display import display, Image

graph = create_decision_workflow()

display(Image(graph.get_graph().draw_mermaid_png()))
